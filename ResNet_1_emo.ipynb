# %% [markdown]
# # Extracting emotion features with ResNet50 pre-trained model
# ## Initial Results

# %%
import pandas as pd
import numpy as np
import os
import glob
from matplotlib.image import imread 
import PIL
from PIL import Image
from numpy import asarray
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
from keras.applications.resnet import preprocess_input
from keras.applications.resnet import ResNet50
from keras.models import Model
from sklearn.model_selection import train_test_split
from sklearn import svm
from sklearn.metrics import confusion_matrix
from keras.preprocessing.image import ImageDataGenerator
import seaborn as sns
import matplotlib.pyplot as plt

import pickle
import h5py
from pickle import dump

# %% [markdown]
# ## Loading and visualising frames

# %%
emotion = pd.read_csv('data/MotionEmotion/reduced_emo_labelled_dataset.csv')
emotion = emotion.rename(columns={'Unnamed: 0':'org_idx'}) 
paths = emotion.path
label = emotion.label
print(len(paths))
for i in range(9):
    plt.subplot(330 + 1 + i)
    #print(file_list[i])
    filename = paths[i]
    image = imread(filename)
    plt.imshow(image)
# Out:
# 4872

# %%
image = Image.open(paths[1])
print(image.format) 
data = asarray(image) #converting image into array
print(data.shape)
# Out:
# JPEG
# (480, 854, 3)

# %% [markdown]
# ## Splitting data to feed into feature extractor
#
# There is a 70/30 split between train and test sets
#
# Furthermore it is stratified due to class imabalance
#
# Test and train sets must be sorted as there is an order on the sequence of frames selected

# %%
def split(emotion):
    X = emotion['path'] #np.array(features).reshape(len(features) ,-1) 
    y = emotion['label']
    x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.3)
    return x_train, x_test, y_train, y_test, X, y

# %%
x_train, x_test, y_train, y_test, X, y = split(emotion)
x_train = x_train.sort_values()
y_train = y_train.sort_index()
x_test = x_test.sort_values()
y_test= y_test.sort_index()

# %% [markdown]
# ## Feeding feature extractor with images
# ### Specifications:
#
# Model: ResNet50 - pretrained
#
# Weights: Imagnet
#
# Input: 224,224
#
# Output: 1, 2048
#
#     Which are the number of features extracted per frame. The last FC layer which carries out the classification
#     is not being used.
#     Layer: avg_pool (GlobalAveragePooling2D) output shape:(none, 2048) # of params: 0 connected to
#        ['conv5_block3_out[0][0]']

# %%
def feature_extraction(images):
    paths = images
    features = []
    for image in paths: 
        images_ = load_img(image, target_size=(224, 224))
        # convert the image pixels to a numpy array
        images_ = img_to_array(images_)
        # reshape data for the model
        images_ = images_.reshape((1, images_.shape[0], images_.shape[1], images_.shape[2])) # prepare the image for the model
        images_ = preprocess_input(images_)
        # load model
        model = ResNet50(weights="imagenet") #include_top=False?
        #model.summary()
        # remove the output layer
        model = Model(inputs=model.inputs, outputs=model.layers[-2].output) #add batch size?
        #model.summary()
        # get extracted features
        features_ = model.predict(images_)
        print(features_.shape)
        features.append(features_)
    model.summary()
    return features

# %%
train_features = feature_extraction(x_train)
test_features = feature_extraction(x_test)
# Out:
# 2022-04-25 12:48:06.104430: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x1714e1040> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# (1, 2048)
# WARNING:tensorflow:6 out of the last 6 calls to <function Model.make_predict_function.<locals>.predict_function at 0x171e30790> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# (1, 2048)
# Model: "model_3409"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3410 (InputLayer)        [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv1_pad (ZeroPadding2D)      (None, 230, 230, 3)  0           ['input_3410[0][0]']
#
#  conv1_conv (Conv2D)            (None, 112, 112, 64  9472        ['conv1_pad[0][0]']
#                                 )
#
#  conv1_bn (BatchNormalization)  (None, 112, 112, 64  256         ['conv1_conv[0][0]']
#                                 )
#
#  conv1_relu (Activation)        (None, 112, 112, 64  0           ['conv1_bn[0][0]']
#                                 )
#
#  pool1_pad (ZeroPadding2D)      (None, 114, 114, 64  0           ['conv1_relu[0][0]']
#                                 )
#
#  pool1_pool (MaxPooling2D)      (None, 56, 56, 64)   0           ['pool1_pad[0][0]']
#
#  conv2_block1_1_conv (Conv2D)   (None, 56, 56, 64)   4160        ['pool1_pool[0][0]']
#
#  conv2_block1_1_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block1_1_conv[0][0]']
#  ization)
#
#  conv2_block1_1_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block1_1_bn[0][0]']
#  n)
#
#  conv2_block1_2_conv (Conv2D)   (None, 56, 56, 64)   36928       ['conv2_block1_1_relu[0][0]']
#
#  conv2_block1_2_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block1_2_conv[0][0]']
#  ization)
#
#  conv2_block1_2_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block1_2_bn[0][0]']
#  n)
#
#  conv2_block1_0_conv (Conv2D)   (None, 56, 56, 256)  16640       ['pool1_pool[0][0]']
#
#  conv2_block1_3_conv (Conv2D)   (None, 56, 56, 256)  16640       ['conv2_block1_2_relu[0][0]']
#
#  conv2_block1_0_bn (BatchNormal  (None, 56, 56, 256)  1024       ['conv2_block1_0_conv[0][0]']
#  ization)
#
#  conv2_block1_3_bn (BatchNormal  (None, 56, 56, 256)  1024       ['conv2_block1_3_conv[0][0]']
#  ization)
#
#  conv2_block1_add (Add)         (None, 56, 56, 256)  0           ['conv2_block1_0_bn[0][0]',
#                                                                   'conv2_block1_3_bn[0][0]']
#
#  conv2_block1_out (Activation)  (None, 56, 56, 256)  0           ['conv2_block1_add[0][0]']
#
#  conv2_block2_1_conv (Conv2D)   (None, 56, 56, 64)   16448       ['conv2_block1_out[0][0]']
#  conv2_block2_1_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block2_1_conv[0][0]']
#  ization)
#
#  conv2_block2_1_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block2_1_bn[0][0]']
#  n)
#
#  conv2_block2_2_conv (Conv2D)   (None, 56, 56, 64)   36928       ['conv2_block2_1_relu[0][0]']
#
#  conv2_block2_2_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block2_2_conv[0][0]']
#  ization)
#
#  conv2_block2_2_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block2_2_bn[0][0]']
#  n)
#
#  conv2_block2_3_conv (Conv2D)   (None, 56, 56, 256)  16640       ['conv2_block2_2_relu[0][0]']
#
#  conv2_block2_3_bn (BatchNormal  (None, 56, 56, 256)  1024       ['conv2_block2_3_conv[0][0]']
#  ization)
#
#  conv2_block2_add (Add)         (None, 56, 56, 256)  0           ['conv2_block1_out[0][0]',
#                                                                   'conv2_block2_3_bn[0][0]']
#
#  conv2_block2_out (Activation)  (None, 56, 56, 256)  0           ['conv2_block2_add[0][0]']
#
#  conv2_block3_1_conv (Conv2D)   (None, 56, 56, 64)   16448       ['conv2_block2_out[0][0]']
#
#  conv2_block3_1_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block3_1_conv[0][0]']
#  ization)
#
#  conv2_block3_1_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block3_1_bn[0][0]']
#  n)
#
#  conv2_block3_2_conv (Conv2D)   (None, 56, 56, 64)   36928       ['conv2_block3_1_relu[0][0]']
#
#  conv2_block3_2_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block3_2_conv[0][0]']
#  ization)
#
#  conv2_block3_2_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block3_2_bn[0][0]']
#  n)
#
#  conv2_block3_3_conv (Conv2D)   (None, 56, 56, 256)  16640       ['conv2_block3_2_relu[0][0]']
#
#  conv2_block3_3_bn (BatchNormal  (None, 56, 56, 256)  1024       ['conv2_block3_3_conv[0][0]']
#  ization)
#
#  conv2_block3_add (Add)         (None, 56, 56, 256)  0           ['conv2_block2_out[0][0]',
#                                                                   'conv2_block3_3_bn[0][0]']
#
#  conv2_block3_out (Activation)  (None, 56, 56, 256)  0           ['conv2_block3_add[0][0]']
#
#  conv3_block1_1_conv (Conv2D)   (None, 28, 28, 128)  32896       ['conv2_block3_out[0][0]']
#
#  conv3_block1_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block1_1_conv[0][0]']
#  ization)
#
#  conv3_block1_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block1_1_bn[0][0]']
#  n)
#
#  conv3_block1_2_conv (Conv2D)   (None, 28, 28, 128)  147584      ['conv3_block1_1_relu[0][0]']
#
#  conv3_block1_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block1_2_conv[0][0]']
#  ization)
#
#  conv3_block1_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block1_2_bn[0][0]']
#  n)
#
#  conv3_block1_0_conv (Conv2D)   (None, 28, 28, 512)  131584      ['conv2_block3_out[0][0]']
#
# ...
#  ization)
#
#  conv4_block4_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block4_2_bn[0][0]']
#  n)
#
#  conv4_block4_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block4_2_relu[0][0]']
#                                 )
#
#  conv4_block4_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block4_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block4_add (Add)         (None, 14, 14, 1024  0           ['conv4_block3_out[0][0]',
#                                 )                                 'conv4_block4_3_bn[0][0]']
#
#  conv4_block4_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block4_add[0][0]']
#                                 )
#
#  conv4_block5_1_conv (Conv2D)   (None, 14, 14, 256)  262400      ['conv4_block4_out[0][0]']
#
#  conv4_block5_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block5_1_conv[0][0]']
#  ization)
#
#  conv4_block5_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block5_1_bn[0][0]']
#  n)
#
#  conv4_block5_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block5_1_relu[0][0]']
#
#  conv4_block5_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block5_2_conv[0][0]']
#  ization)
#
#  conv4_block5_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block5_2_bn[0][0]']
#  n)
#
#  conv4_block5_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block5_2_relu[0][0]']
#                                 )
#
#  conv4_block5_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block5_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block5_add (Add)         (None, 14, 14, 1024  0           ['conv4_block4_out[0][0]',
#                                 )                                 'conv4_block5_3_bn[0][0]']
#
#  conv4_block5_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block5_add[0][0]']
#                                 )
#
#  conv4_block6_1_conv (Conv2D)   (None, 14, 14, 256)  262400      ['conv4_block5_out[0][0]']
#
#  conv4_block6_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block6_1_conv[0][0]']
#  ization)
#
#  conv4_block6_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block6_1_bn[0][0]']
#  n)
#
#  conv4_block6_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block6_1_relu[0][0]']
#
#  conv4_block6_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block6_2_conv[0][0]']
#  ization)
#
#  conv4_block6_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block6_2_bn[0][0]']
#  n)
#
#  conv4_block6_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block6_2_relu[0][0]']
#                                 )
#
#  conv4_block6_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block6_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block6_add (Add)         (None, 14, 14, 1024  0           ['conv4_block5_out[0][0]',
#                                 )                                 'conv4_block6_3_bn[0][0]']
#
#  conv4_block6_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block6_add[0][0]']
#                                 )
#
#  conv5_block1_1_conv (Conv2D)   (None, 7, 7, 512)    524800      ['conv4_block6_out[0][0]']
#
#  conv5_block1_1_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block1_1_conv[0][0]']
#  ization)
#
#  conv5_block1_1_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block1_1_bn[0][0]']
#  n)
#
#  conv5_block1_2_conv (Conv2D)   (None, 7, 7, 512)    2359808     ['conv5_block1_1_relu[0][0]']
#
#  conv5_block1_2_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block1_2_conv[0][0]']
#  ization)
#
#  conv5_block1_2_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block1_2_bn[0][0]']
#  n)
#
#  conv5_block1_0_conv (Conv2D)   (None, 7, 7, 2048)   2099200     ['conv4_block6_out[0][0]']
#
#  conv5_block1_3_conv (Conv2D)   (None, 7, 7, 2048)   1050624     ['conv5_block1_2_relu[0][0]']
#
#  conv5_block1_0_bn (BatchNormal  (None, 7, 7, 2048)  8192        ['conv5_block1_0_conv[0][0]']
#  ization)
#
#  conv5_block1_3_bn (BatchNormal  (None, 7, 7, 2048)  8192        ['conv5_block1_3_conv[0][0]']
#  ization)
#
#  conv5_block1_add (Add)         (None, 7, 7, 2048)   0           ['conv5_block1_0_bn[0][0]',
#                                                                   'conv5_block1_3_bn[0][0]']
#
#  conv5_block1_out (Activation)  (None, 7, 7, 2048)   0           ['conv5_block1_add[0][0]']
#
#  conv5_block2_1_conv (Conv2D)   (None, 7, 7, 512)    1049088     ['conv5_block1_out[0][0]']
#
#  conv5_block2_1_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block2_1_conv[0][0]']
#  ization)
#
#  conv5_block2_1_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block2_1_bn[0][0]']
#  n)
#
#  conv5_block2_2_conv (Conv2D)   (None, 7, 7, 512)    2359808     ['conv5_block2_1_relu[0][0]']
#
#  conv5_block2_2_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block2_2_conv[0][0]']
#  ization)
#
#  conv5_block2_2_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block2_2_bn[0][0]']
#  n)
#
#  conv5_block2_3_conv (Conv2D)   (None, 7, 7, 2048)   1050624     ['conv5_block2_2_relu[0][0]']
#
#  conv5_block2_3_bn (BatchNormal  (None, 7, 7, 2048)  8192        ['conv5_block2_3_conv[0][0]']
#  ization)
#
#  conv5_block2_add (Add)         (None, 7, 7, 2048)   0           ['conv5_block1_out[0][0]',
#                                                                   'conv5_block2_3_bn[0][0]']
#
#  conv5_block2_out (Activation)  (None, 7, 7, 2048)   0           ['conv5_block2_add[0][0]']
#
#  conv5_block3_1_conv (Conv2D)   (None, 7, 7, 512)    1049088     ['conv5_block2_out[0][0]']
#
#  conv5_block3_1_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block3_1_conv[0][0]']
#  ization)
#
#  conv5_block3_1_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block3_1_bn[0][0]']
#  n)
#
#  conv5_block3_2_conv (Conv2D)   (None, 7, 7, 512)    2359808     ['conv5_block3_1_relu[0][0]']
#
#  conv5_block3_2_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block3_2_conv[0][0]']
#  ization)
#
#  conv5_block3_2_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block3_2_bn[0][0]']
#  n)
#
#  conv5_block3_3_conv (Conv2D)   (None, 7, 7, 2048)   1050624     ['conv5_block3_2_relu[0][0]']
#
#  conv5_block3_3_bn (BatchNormal  (None, 7, 7, 2048)  8192        ['conv5_block3_3_conv[0][0]']
#  ization)
#
#  conv5_block3_add (Add)         (None, 7, 7, 2048)   0           ['conv5_block2_out[0][0]',
#                                                                   'conv5_block3_3_bn[0][0]']
#
#  conv5_block3_out (Activation)  (None, 7, 7, 2048)   0           ['conv5_block3_add[0][0]']
#
#  avg_pool (GlobalAveragePooling  (None, 2048)        0           ['conv5_block3_out[0][0]']
#  2D)
#
# ==================================================================================================
# Total params: 23,587,712
# Trainable params: 23,534,592
# Non-trainable params: 53,120
# __________________________________________________________________________________________________

# %%
from numpy import savetxt
k=0 
for i in train_features:
    #print(i)
    k +=1
    #print(j)
    savetxt('data/all_features/ResNet2048_emo/data'+ str(k) +'.csv', i, delimiter=',')

# %% [markdown]
# ### Reshaping features to feed into GridSearch and classifiers

# %%
from sklearn.svm import SVC
from sklearn.model_selection import RandomizedSearchCV
from sklearn.preprocessing import StandardScaler
import scipy

train_features = np.array(train_features).reshape(len(train_features) ,-1) 
train_features = StandardScaler().fit_transform(train_features)

test_features = np.array(test_features).reshape(len(test_features) ,-1) 
test_features = StandardScaler().fit_transform(test_features)

# %% [markdown]
# ## Searching for best parameters for each SVM

# %%
from sklearn.metrics import classification_report
'''
Linear
'''
param_grid_l = {'C': scipy.stats.expon(scale=100), 'gamma': scipy.stats.expon(scale=.1),'kernel': ['linear']}
grid_l = RandomizedSearchCV(SVC(),param_grid_l,refit=True,verbose=2)
grid_l.fit(train_features, y_train)
print(grid_l.best_params_)
grid_predictions_l = grid_l.predict(test_features)
print(confusion_matrix(y_test, grid_predictions_l))
print(classification_report(y_test,grid_predictions_l))
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV] END C=336.32761349598906, gamma=0.12037894667795149, kernel=linear; total time=   3.6s
# [CV] END C=336.32761349598906, gamma=0.12037894667795149, kernel=linear; total time=   3.4s
# [CV] END C=336.32761349598906, gamma=0.12037894667795149, kernel=linear; total time=   4.1s
# [CV] END C=336.32761349598906, gamma=0.12037894667795149, kernel=linear; total time=   4.3s
# [CV] END C=336.32761349598906, gamma=0.12037894667795149, kernel=linear; total time=   3.6s
# [CV] END C=41.55552298932596, gamma=0.07230628013008393, kernel=linear; total time=   3.5s
# [CV] END C=41.55552298932596, gamma=0.07230628013008393, kernel=linear; total time=   4.0s
# [CV] END C=41.55552298932596, gamma=0.07230628013008393, kernel=linear; total time=   4.5s
# [CV] END C=41.55552298932596, gamma=0.07230628013008393, kernel=linear; total time=   5.1s
# [CV] END C=41.55552298932596, gamma=0.07230628013008393, kernel=linear; total time=   5.1s
# [CV] END C=396.45254030784247, gamma=0.0032165728880340205, kernel=linear; total time=   5.7s
# [CV] END C=396.45254030784247, gamma=0.0032165728880340205, kernel=linear; total time=   5.8s
# [CV] END C=396.45254030784247, gamma=0.0032165728880340205, kernel=linear; total time=   5.4s
# [CV] END C=396.45254030784247, gamma=0.0032165728880340205, kernel=linear; total time=   4.6s
# [CV] END C=396.45254030784247, gamma=0.0032165728880340205, kernel=linear; total time=   4.7s
# [CV] END C=21.592308094379, gamma=0.029206237468491766, kernel=linear; total time=   4.7s
# [CV] END C=21.592308094379, gamma=0.029206237468491766, kernel=linear; total time=   5.7s
# [CV] END C=21.592308094379, gamma=0.029206237468491766, kernel=linear; total time=   5.7s
# [CV] END C=21.592308094379, gamma=0.029206237468491766, kernel=linear; total time=   4.7s
# [CV] END C=21.592308094379, gamma=0.029206237468491766, kernel=linear; total time=   4.7s
# [CV] END C=56.92915301863081, gamma=0.3800154359940078, kernel=linear; total time=   4.5s
# [CV] END C=56.92915301863081, gamma=0.3800154359940078, kernel=linear; total time=   4.7s
# [CV] END C=56.92915301863081, gamma=0.3800154359940078, kernel=linear; total time=   4.8s
# [CV] END C=56.92915301863081, gamma=0.3800154359940078, kernel=linear; total time=   4.8s
# [CV] END C=56.92915301863081, gamma=0.3800154359940078, kernel=linear; total time=   5.9s
# [CV] END C=41.98110312361171, gamma=0.14287458421131768, kernel=linear; total time=   5.8s
# [CV] END C=41.98110312361171, gamma=0.14287458421131768, kernel=linear; total time=   5.9s
# [CV] END C=41.98110312361171, gamma=0.14287458421131768, kernel=linear; total time=   5.5s
# [CV] END C=41.98110312361171, gamma=0.14287458421131768, kernel=linear; total time=   5.5s
# [CV] END C=41.98110312361171, gamma=0.14287458421131768, kernel=linear; total time=   6.0s
# [CV] END C=74.04341132177532, gamma=0.01989209957636911, kernel=linear; total time=   5.3s
# [CV] END C=74.04341132177532, gamma=0.01989209957636911, kernel=linear; total time=   6.5s
# [CV] END C=74.04341132177532, gamma=0.01989209957636911, kernel=linear; total time=   6.2s
# [CV] END C=74.04341132177532, gamma=0.01989209957636911, kernel=linear; total time=   5.7s
# [CV] END C=74.04341132177532, gamma=0.01989209957636911, kernel=linear; total time=   4.7s
# [CV] END C=164.31250532322125, gamma=0.10845964880209016, kernel=linear; total time=   4.7s
# [CV] END C=164.31250532322125, gamma=0.10845964880209016, kernel=linear; total time=   4.4s
# [CV] END C=164.31250532322125, gamma=0.10845964880209016, kernel=linear; total time=   5.0s
# [CV] END C=164.31250532322125, gamma=0.10845964880209016, kernel=linear; total time=   4.9s
# [CV] END C=164.31250532322125, gamma=0.10845964880209016, kernel=linear; total time=   4.1s
# [CV] END C=60.480103548090334, gamma=0.07179169690106284, kernel=linear; total time=   4.7s
# [CV] END C=60.480103548090334, gamma=0.07179169690106284, kernel=linear; total time=   4.5s
# [CV] END C=60.480103548090334, gamma=0.07179169690106284, kernel=linear; total time=   4.8s
# [CV] END C=60.480103548090334, gamma=0.07179169690106284, kernel=linear; total time=   4.6s
# [CV] END C=60.480103548090334, gamma=0.07179169690106284, kernel=linear; total time=   4.8s
# [CV] END C=90.8754381488314, gamma=0.036685492112195475, kernel=linear; total time=   4.2s
# [CV] END C=90.8754381488314, gamma=0.036685492112195475, kernel=linear; total time=   4.7s
# [CV] END C=90.8754381488314, gamma=0.036685492112195475, kernel=linear; total time=   4.6s
# [CV] END C=90.8754381488314, gamma=0.036685492112195475, kernel=linear; total time=   4.8s
# [CV] END C=90.8754381488314, gamma=0.036685492112195475, kernel=linear; total time=   4.7s
# {'C': 336.32761349598906, 'gamma': 0.12037894667795149, 'kernel': 'linear'}
# [[234   0   0   0   0   0]
#  [  0  78   0   0   0   0]
#  [  0   0 189   0   0   0]
#  [  0   0   0 234   0   0]
#  [  0   0   0   0  45   0]
#  [  0   0   0   0   0 682]]
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00       234
#            2       1.00      1.00      1.00        78
#            3       1.00      1.00      1.00       189
#            4       1.00      1.00      1.00       234
#            5       1.00      1.00      1.00        45
#            6       1.00      1.00      1.00       682
#
#     accuracy                           1.00      1462
#    macro avg       1.00      1.00      1.00      1462
# weighted avg       1.00      1.00      1.00      1462

# %%
'''
Radial
'''
param_grid_r = {'C': scipy.stats.expon(scale=100), 'gamma': scipy.stats.expon(scale=.1),'kernel': ['rbf']}
grid_r = RandomizedSearchCV(SVC(),param_grid_r,refit=True,verbose=2)
grid_r.fit(train_features, y_train)
print(grid_r.best_params_)
grid_predictions_r = grid_r.predict(test_features)
print(confusion_matrix(y_test, grid_predictions_r))
print(classification_report(y_test,grid_predictions_r))
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV] END C=84.04576844742057, gamma=0.22598309183747556, kernel=rbf; total time=  31.5s
# [CV] END C=84.04576844742057, gamma=0.22598309183747556, kernel=rbf; total time=  31.2s
# [CV] END C=84.04576844742057, gamma=0.22598309183747556, kernel=rbf; total time=  31.1s
# [CV] END C=84.04576844742057, gamma=0.22598309183747556, kernel=rbf; total time=  31.3s
# [CV] END C=84.04576844742057, gamma=0.22598309183747556, kernel=rbf; total time=  31.4s
# [CV] END C=11.849861698134152, gamma=0.12515779833893756, kernel=rbf; total time=  32.3s
# [CV] END C=11.849861698134152, gamma=0.12515779833893756, kernel=rbf; total time=  33.4s
# [CV] END C=11.849861698134152, gamma=0.12515779833893756, kernel=rbf; total time=  36.6s
# [CV] END C=11.849861698134152, gamma=0.12515779833893756, kernel=rbf; total time=  38.1s
# [CV] END C=11.849861698134152, gamma=0.12515779833893756, kernel=rbf; total time=  38.4s
# [CV] END C=289.7308039279275, gamma=0.09905233297142707, kernel=rbf; total time=  37.4s
# [CV] END C=289.7308039279275, gamma=0.09905233297142707, kernel=rbf; total time=  32.4s
# [CV] END C=289.7308039279275, gamma=0.09905233297142707, kernel=rbf; total time=  32.3s
# [CV] END C=289.7308039279275, gamma=0.09905233297142707, kernel=rbf; total time=  32.4s
# [CV] END C=289.7308039279275, gamma=0.09905233297142707, kernel=rbf; total time=  25.8s
# [CV] END C=12.068610374475403, gamma=0.0717930291498763, kernel=rbf; total time=  23.7s
# [CV] END C=12.068610374475403, gamma=0.0717930291498763, kernel=rbf; total time=  29.2s
# [CV] END C=12.068610374475403, gamma=0.0717930291498763, kernel=rbf; total time=  34.7s
# [CV] END C=12.068610374475403, gamma=0.0717930291498763, kernel=rbf; total time=  27.1s
# [CV] END C=12.068610374475403, gamma=0.0717930291498763, kernel=rbf; total time=  23.9s
# [CV] END C=25.872515083467384, gamma=0.08626222316673038, kernel=rbf; total time=  23.6s
# [CV] END C=25.872515083467384, gamma=0.08626222316673038, kernel=rbf; total time=  23.7s
# [CV] END C=25.872515083467384, gamma=0.08626222316673038, kernel=rbf; total time=  23.2s
# [CV] END C=25.872515083467384, gamma=0.08626222316673038, kernel=rbf; total time=  23.6s
# [CV] END C=25.872515083467384, gamma=0.08626222316673038, kernel=rbf; total time=  23.5s
# [CV] END C=9.336111831246445, gamma=0.055977735879274265, kernel=rbf; total time=  23.4s
# [CV] END C=9.336111831246445, gamma=0.055977735879274265, kernel=rbf; total time=  23.4s
# [CV] END C=9.336111831246445, gamma=0.055977735879274265, kernel=rbf; total time=  23.4s
# [CV] END C=9.336111831246445, gamma=0.055977735879274265, kernel=rbf; total time=  24.3s
# [CV] END C=9.336111831246445, gamma=0.055977735879274265, kernel=rbf; total time=  25.3s
# [CV] END C=67.70048470377439, gamma=0.010356776252484223, kernel=rbf; total time=  30.9s
# [CV] END C=67.70048470377439, gamma=0.010356776252484223, kernel=rbf; total time=  32.4s
# [CV] END C=67.70048470377439, gamma=0.010356776252484223, kernel=rbf; total time=  32.9s
# [CV] END C=67.70048470377439, gamma=0.010356776252484223, kernel=rbf; total time=  23.0s
# [CV] END C=67.70048470377439, gamma=0.010356776252484223, kernel=rbf; total time=  24.0s
# [CV] END C=9.76760468068622, gamma=0.028785096307507436, kernel=rbf; total time=  23.5s
# [CV] END C=9.76760468068622, gamma=0.028785096307507436, kernel=rbf; total time=  18.3s
# [CV] END C=9.76760468068622, gamma=0.028785096307507436, kernel=rbf; total time=  16.7s
# [CV] END C=9.76760468068622, gamma=0.028785096307507436, kernel=rbf; total time=  16.9s
# [CV] END C=9.76760468068622, gamma=0.028785096307507436, kernel=rbf; total time=  16.7s
# [CV] END C=30.13360559441358, gamma=0.05952359843391275, kernel=rbf; total time=  16.9s
# [CV] END C=30.13360559441358, gamma=0.05952359843391275, kernel=rbf; total time=  16.9s
# [CV] END C=30.13360559441358, gamma=0.05952359843391275, kernel=rbf; total time=  16.9s
# [CV] END C=30.13360559441358, gamma=0.05952359843391275, kernel=rbf; total time=  16.9s
# [CV] END C=30.13360559441358, gamma=0.05952359843391275, kernel=rbf; total time=  17.7s
# [CV] END C=596.2994393660792, gamma=0.22196131583206538, kernel=rbf; total time=  22.1s
# [CV] END C=596.2994393660792, gamma=0.22196131583206538, kernel=rbf; total time=  22.7s
# [CV] END C=596.2994393660792, gamma=0.22196131583206538, kernel=rbf; total time=  18.9s
# [CV] END C=596.2994393660792, gamma=0.22196131583206538, kernel=rbf; total time=  17.0s
# [CV] END C=596.2994393660792, gamma=0.22196131583206538, kernel=rbf; total time=  17.0s
# {'C': 84.04576844742057, 'gamma': 0.22598309183747556, 'kernel': 'rbf'}
# [[  0   0   0   0   0 234]
#  [  0   0   0   0   0  78]
#  [  0   0   0   0   0 189]
#  [  0   0   0   0   0 234]
#  [  0   0   0   0   0  45]
#  [  0   0   0   0   0 682]]
#               precision    recall  f1-score   support
#
#            1       0.00      0.00      0.00       234
#            2       0.00      0.00      0.00        78
#            3       0.00      0.00      0.00       189
#            4       0.00      0.00      0.00       234
#            5       0.00      0.00      0.00        45
#            6       0.47      1.00      0.64       682
#
#     accuracy                           0.47      1462
#    macro avg       0.08      0.17      0.11      1462
# weighted avg       0.22      0.47      0.30      1462
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
from sklearn.model_selection import GridSearchCV
'''
Polynomial
'''
param_grid_p = { 'C': [0.1,1, 10], 'gamma': [0.001, 0.01, 1 ],'degree':[0.5, 1, 2, 3] ,'kernel': ['poly']}
grid_p = GridSearchCV(SVC(),param_grid_p,refit=True,verbose=2)
grid_p.fit(train_features, y_train)
print(grid_p.best_params_)
grid_predictions_p = grid_p.predict(test_features)
print(confusion_matrix(y_test, grid_predictions_p))
print(classification_report(y_test,grid_predictions_p))
# Out:
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# [CV] END ........C=0.1, degree=0.5, gamma=0.001, kernel=poly; total time=   7.6s
# [CV] END ........C=0.1, degree=0.5, gamma=0.001, kernel=poly; total time=   8.9s
# [CV] END ........C=0.1, degree=0.5, gamma=0.001, kernel=poly; total time=   8.6s
# [CV] END ........C=0.1, degree=0.5, gamma=0.001, kernel=poly; total time=   8.7s
# [CV] END ........C=0.1, degree=0.5, gamma=0.001, kernel=poly; total time=   7.7s
# [CV] END .........C=0.1, degree=0.5, gamma=0.01, kernel=poly; total time=   7.6s
# [CV] END .........C=0.1, degree=0.5, gamma=0.01, kernel=poly; total time=   8.5s
# [CV] END .........C=0.1, degree=0.5, gamma=0.01, kernel=poly; total time=   9.0s
# [CV] END .........C=0.1, degree=0.5, gamma=0.01, kernel=poly; total time=   9.2s
# [CV] END .........C=0.1, degree=0.5, gamma=0.01, kernel=poly; total time=   8.9s
# [CV] END ............C=0.1, degree=0.5, gamma=1, kernel=poly; total time=   7.0s
# [CV] END ............C=0.1, degree=0.5, gamma=1, kernel=poly; total time=   6.9s
# [CV] END ............C=0.1, degree=0.5, gamma=1, kernel=poly; total time=   7.0s
# [CV] END ............C=0.1, degree=0.5, gamma=1, kernel=poly; total time=   6.8s
# [CV] END ............C=0.1, degree=0.5, gamma=1, kernel=poly; total time=   6.7s
# [CV] END ..........C=0.1, degree=1, gamma=0.001, kernel=poly; total time=   5.3s
# [CV] END ..........C=0.1, degree=1, gamma=0.001, kernel=poly; total time=   5.2s
# [CV] END ..........C=0.1, degree=1, gamma=0.001, kernel=poly; total time=   5.4s
# [CV] END ..........C=0.1, degree=1, gamma=0.001, kernel=poly; total time=   5.3s
# [CV] END ..........C=0.1, degree=1, gamma=0.001, kernel=poly; total time=   5.1s
# [CV] END ...........C=0.1, degree=1, gamma=0.01, kernel=poly; total time=   2.5s
# [CV] END ...........C=0.1, degree=1, gamma=0.01, kernel=poly; total time=   2.5s
# [CV] END ...........C=0.1, degree=1, gamma=0.01, kernel=poly; total time=   2.7s
# [CV] END ...........C=0.1, degree=1, gamma=0.01, kernel=poly; total time=   2.5s
# [CV] END ...........C=0.1, degree=1, gamma=0.01, kernel=poly; total time=   2.4s
# [CV] END ..............C=0.1, degree=1, gamma=1, kernel=poly; total time=   2.4s
# [CV] END ..............C=0.1, degree=1, gamma=1, kernel=poly; total time=   2.4s
# [CV] END ..............C=0.1, degree=1, gamma=1, kernel=poly; total time=   2.6s
# [CV] END ..............C=0.1, degree=1, gamma=1, kernel=poly; total time=   2.4s
# [CV] END ..............C=0.1, degree=1, gamma=1, kernel=poly; total time=   2.4s
# [CV] END ..........C=0.1, degree=2, gamma=0.001, kernel=poly; total time=   5.4s
# [CV] END ..........C=0.1, degree=2, gamma=0.001, kernel=poly; total time=   5.4s
# [CV] END ..........C=0.1, degree=2, gamma=0.001, kernel=poly; total time=   6.6s
# [CV] END ..........C=0.1, degree=2, gamma=0.001, kernel=poly; total time=   6.5s
# [CV] END ..........C=0.1, degree=2, gamma=0.001, kernel=poly; total time=   6.1s
# [CV] END ...........C=0.1, degree=2, gamma=0.01, kernel=poly; total time=   5.0s
# [CV] END ...........C=0.1, degree=2, gamma=0.01, kernel=poly; total time=   5.2s
# [CV] END ...........C=0.1, degree=2, gamma=0.01, kernel=poly; total time=   6.4s
# [CV] END ...........C=0.1, degree=2, gamma=0.01, kernel=poly; total time=   4.7s
# [CV] END ...........C=0.1, degree=2, gamma=0.01, kernel=poly; total time=   4.8s
# [CV] END ..............C=0.1, degree=2, gamma=1, kernel=poly; total time=   5.3s
# [CV] END ..............C=0.1, degree=2, gamma=1, kernel=poly; total time=   6.1s
# [CV] END ..............C=0.1, degree=2, gamma=1, kernel=poly; total time=   6.0s
# [CV] END ..............C=0.1, degree=2, gamma=1, kernel=poly; total time=   5.8s
# [CV] END ..............C=0.1, degree=2, gamma=1, kernel=poly; total time=   5.9s
# [CV] END ..........C=0.1, degree=3, gamma=0.001, kernel=poly; total time=   9.4s
# [CV] END ..........C=0.1, degree=3, gamma=0.001, kernel=poly; total time=   9.5s
# [CV] END ..........C=0.1, degree=3, gamma=0.001, kernel=poly; total time=  10.1s
# [CV] END ..........C=0.1, degree=3, gamma=0.001, kernel=poly; total time=   9.6s
# [CV] END ..........C=0.1, degree=3, gamma=0.001, kernel=poly; total time=   8.2s
# [CV] END ...........C=0.1, degree=3, gamma=0.01, kernel=poly; total time=   7.8s
# [CV] END ...........C=0.1, degree=3, gamma=0.01, kernel=poly; total time=   7.7s
# [CV] END ...........C=0.1, degree=3, gamma=0.01, kernel=poly; total time=   7.8s
# [CV] END ...........C=0.1, degree=3, gamma=0.01, kernel=poly; total time=   7.8s
# [CV] END ...........C=0.1, degree=3, gamma=0.01, kernel=poly; total time=   7.7s
# [CV] END ..............C=0.1, degree=3, gamma=1, kernel=poly; total time=   7.8s
# [CV] END ..............C=0.1, degree=3, gamma=1, kernel=poly; total time=   7.8s
# [CV] END ..............C=0.1, degree=3, gamma=1, kernel=poly; total time=   7.9s
# [CV] END ..............C=0.1, degree=3, gamma=1, kernel=poly; total time=   8.1s
# [CV] END ..............C=0.1, degree=3, gamma=1, kernel=poly; total time=   7.5s
# [CV] END ..........C=1, degree=0.5, gamma=0.001, kernel=poly; total time=   9.2s
# [CV] END ..........C=1, degree=0.5, gamma=0.001, kernel=poly; total time=   9.1s
# [CV] END ..........C=1, degree=0.5, gamma=0.001, kernel=poly; total time=   9.1s
# [CV] END ..........C=1, degree=0.5, gamma=0.001, kernel=poly; total time=   9.2s
# [CV] END ..........C=1, degree=0.5, gamma=0.001, kernel=poly; total time=   9.2s
# [CV] END ...........C=1, degree=0.5, gamma=0.01, kernel=poly; total time=   9.0s
# [CV] END ...........C=1, degree=0.5, gamma=0.01, kernel=poly; total time=   9.1s
# [CV] END ...........C=1, degree=0.5, gamma=0.01, kernel=poly; total time=   9.2s
# [CV] END ...........C=1, degree=0.5, gamma=0.01, kernel=poly; total time=   9.2s
# [CV] END ...........C=1, degree=0.5, gamma=0.01, kernel=poly; total time=   9.1s
# [CV] END ..............C=1, degree=0.5, gamma=1, kernel=poly; total time=   9.1s
# [CV] END ..............C=1, degree=0.5, gamma=1, kernel=poly; total time=   9.2s
# [CV] END ..............C=1, degree=0.5, gamma=1, kernel=poly; total time=   9.0s
# [CV] END ..............C=1, degree=0.5, gamma=1, kernel=poly; total time=   9.2s
# [CV] END ..............C=1, degree=0.5, gamma=1, kernel=poly; total time=   9.1s
# [CV] END ............C=1, degree=1, gamma=0.001, kernel=poly; total time=   3.1s
# [CV] END ............C=1, degree=1, gamma=0.001, kernel=poly; total time=   3.2s
# [CV] END ............C=1, degree=1, gamma=0.001, kernel=poly; total time=   3.5s
# [CV] END ............C=1, degree=1, gamma=0.001, kernel=poly; total time=   3.2s
# [CV] END ............C=1, degree=1, gamma=0.001, kernel=poly; total time=   3.2s
# [CV] END .............C=1, degree=1, gamma=0.01, kernel=poly; total time=   3.0s
# [CV] END .............C=1, degree=1, gamma=0.01, kernel=poly; total time=   3.1s
# [CV] END .............C=1, degree=1, gamma=0.01, kernel=poly; total time=   3.3s
# [CV] END .............C=1, degree=1, gamma=0.01, kernel=poly; total time=   3.1s
# [CV] END .............C=1, degree=1, gamma=0.01, kernel=poly; total time=   3.1s
# [CV] END ................C=1, degree=1, gamma=1, kernel=poly; total time=   3.0s
# [CV] END ................C=1, degree=1, gamma=1, kernel=poly; total time=   3.2s
# [CV] END ................C=1, degree=1, gamma=1, kernel=poly; total time=   3.3s
# [CV] END ................C=1, degree=1, gamma=1, kernel=poly; total time=   3.1s
# [CV] END ................C=1, degree=1, gamma=1, kernel=poly; total time=   3.1s
# [CV] END ............C=1, degree=2, gamma=0.001, kernel=poly; total time=   5.9s
# [CV] END ............C=1, degree=2, gamma=0.001, kernel=poly; total time=   6.0s
# [CV] END ............C=1, degree=2, gamma=0.001, kernel=poly; total time=   5.9s
# [CV] END ............C=1, degree=2, gamma=0.001, kernel=poly; total time=   5.8s
# [CV] END ............C=1, degree=2, gamma=0.001, kernel=poly; total time=   6.0s
# [CV] END .............C=1, degree=2, gamma=0.01, kernel=poly; total time=   5.7s
# [CV] END .............C=1, degree=2, gamma=0.01, kernel=poly; total time=   6.0s
# [CV] END .............C=1, degree=2, gamma=0.01, kernel=poly; total time=   5.9s
# [CV] END .............C=1, degree=2, gamma=0.01, kernel=poly; total time=   6.0s
# [CV] END .............C=1, degree=2, gamma=0.01, kernel=poly; total time=   5.8s
# [CV] END ................C=1, degree=2, gamma=1, kernel=poly; total time=   5.8s
# [CV] END ................C=1, degree=2, gamma=1, kernel=poly; total time=   6.0s
# [CV] END ................C=1, degree=2, gamma=1, kernel=poly; total time=   6.0s
# [CV] END ................C=1, degree=2, gamma=1, kernel=poly; total time=   6.0s
# [CV] END ................C=1, degree=2, gamma=1, kernel=poly; total time=   5.9s
# [CV] END ............C=1, degree=3, gamma=0.001, kernel=poly; total time=   7.8s
# [CV] END ............C=1, degree=3, gamma=0.001, kernel=poly; total time=   7.8s
# [CV] END ............C=1, degree=3, gamma=0.001, kernel=poly; total time=   7.6s
# [CV] END ............C=1, degree=3, gamma=0.001, kernel=poly; total time=   7.7s
# [CV] END ............C=1, degree=3, gamma=0.001, kernel=poly; total time=   7.6s
# [CV] END .............C=1, degree=3, gamma=0.01, kernel=poly; total time=   7.8s
# [CV] END .............C=1, degree=3, gamma=0.01, kernel=poly; total time=   7.9s
# [CV] END .............C=1, degree=3, gamma=0.01, kernel=poly; total time=   7.7s
# [CV] END .............C=1, degree=3, gamma=0.01, kernel=poly; total time=   7.8s
# [CV] END .............C=1, degree=3, gamma=0.01, kernel=poly; total time=   7.6s
# [CV] END ................C=1, degree=3, gamma=1, kernel=poly; total time=   7.6s
# [CV] END ................C=1, degree=3, gamma=1, kernel=poly; total time=   7.9s
# [CV] END ................C=1, degree=3, gamma=1, kernel=poly; total time=   7.9s
# [CV] END ................C=1, degree=3, gamma=1, kernel=poly; total time=   7.9s
# [CV] END ................C=1, degree=3, gamma=1, kernel=poly; total time=   7.7s
# [CV] END .........C=10, degree=0.5, gamma=0.001, kernel=poly; total time=   9.1s
# [CV] END .........C=10, degree=0.5, gamma=0.001, kernel=poly; total time=   9.3s
# [CV] END .........C=10, degree=0.5, gamma=0.001, kernel=poly; total time=   9.1s
# [CV] END .........C=10, degree=0.5, gamma=0.001, kernel=poly; total time=   9.2s
# [CV] END .........C=10, degree=0.5, gamma=0.001, kernel=poly; total time=   9.1s
# [CV] END ..........C=10, degree=0.5, gamma=0.01, kernel=poly; total time=   9.1s
# [CV] END ..........C=10, degree=0.5, gamma=0.01, kernel=poly; total time=   9.1s
# [CV] END ..........C=10, degree=0.5, gamma=0.01, kernel=poly; total time=   9.2s
# [CV] END ..........C=10, degree=0.5, gamma=0.01, kernel=poly; total time=   9.9s
# [CV] END ..........C=10, degree=0.5, gamma=0.01, kernel=poly; total time=   8.9s
# [CV] END .............C=10, degree=0.5, gamma=1, kernel=poly; total time=   9.2s
# [CV] END .............C=10, degree=0.5, gamma=1, kernel=poly; total time=   8.9s
# [CV] END .............C=10, degree=0.5, gamma=1, kernel=poly; total time=   9.0s
# [CV] END .............C=10, degree=0.5, gamma=1, kernel=poly; total time=   8.9s
# [CV] END .............C=10, degree=0.5, gamma=1, kernel=poly; total time=   9.2s
# [CV] END ...........C=10, degree=1, gamma=0.001, kernel=poly; total time=   3.1s
# [CV] END ...........C=10, degree=1, gamma=0.001, kernel=poly; total time=   3.0s
# [CV] END ...........C=10, degree=1, gamma=0.001, kernel=poly; total time=   3.4s
# [CV] END ...........C=10, degree=1, gamma=0.001, kernel=poly; total time=   3.1s
# [CV] END ...........C=10, degree=1, gamma=0.001, kernel=poly; total time=   3.0s
# [CV] END ............C=10, degree=1, gamma=0.01, kernel=poly; total time=   3.0s
# [CV] END ............C=10, degree=1, gamma=0.01, kernel=poly; total time=   3.2s
# [CV] END ............C=10, degree=1, gamma=0.01, kernel=poly; total time=   3.3s
# [CV] END ............C=10, degree=1, gamma=0.01, kernel=poly; total time=   3.2s
# [CV] END ............C=10, degree=1, gamma=0.01, kernel=poly; total time=   3.1s
# [CV] END ...............C=10, degree=1, gamma=1, kernel=poly; total time=   3.1s
# [CV] END ...............C=10, degree=1, gamma=1, kernel=poly; total time=   3.0s
# [CV] END ...............C=10, degree=1, gamma=1, kernel=poly; total time=   3.4s
# [CV] END ...............C=10, degree=1, gamma=1, kernel=poly; total time=   3.1s
# [CV] END ...............C=10, degree=1, gamma=1, kernel=poly; total time=   3.1s
# [CV] END ...........C=10, degree=2, gamma=0.001, kernel=poly; total time=   5.8s
# [CV] END ...........C=10, degree=2, gamma=0.001, kernel=poly; total time=   5.9s
# [CV] END ...........C=10, degree=2, gamma=0.001, kernel=poly; total time=   5.9s
# [CV] END ...........C=10, degree=2, gamma=0.001, kernel=poly; total time=   5.9s
# [CV] END ...........C=10, degree=2, gamma=0.001, kernel=poly; total time=   5.8s
# [CV] END ............C=10, degree=2, gamma=0.01, kernel=poly; total time=   5.7s
# [CV] END ............C=10, degree=2, gamma=0.01, kernel=poly; total time=   6.1s
# [CV] END ............C=10, degree=2, gamma=0.01, kernel=poly; total time=   5.9s
# [CV] END ............C=10, degree=2, gamma=0.01, kernel=poly; total time=   5.9s
# [CV] END ............C=10, degree=2, gamma=0.01, kernel=poly; total time=   5.8s
# [CV] END ...............C=10, degree=2, gamma=1, kernel=poly; total time=   5.7s
# [CV] END ...............C=10, degree=2, gamma=1, kernel=poly; total time=   6.1s
# [CV] END ...............C=10, degree=2, gamma=1, kernel=poly; total time=   5.9s
# [CV] END ...............C=10, degree=2, gamma=1, kernel=poly; total time=   5.8s
# [CV] END ...............C=10, degree=2, gamma=1, kernel=poly; total time=   5.8s
# [CV] END ...........C=10, degree=3, gamma=0.001, kernel=poly; total time=   7.7s
# [CV] END ...........C=10, degree=3, gamma=0.001, kernel=poly; total time=   7.8s
# [CV] END ...........C=10, degree=3, gamma=0.001, kernel=poly; total time=   7.7s
# [CV] END ...........C=10, degree=3, gamma=0.001, kernel=poly; total time=   7.7s
# [CV] END ...........C=10, degree=3, gamma=0.001, kernel=poly; total time=   7.6s
# [CV] END ............C=10, degree=3, gamma=0.01, kernel=poly; total time=   7.6s
# [CV] END ............C=10, degree=3, gamma=0.01, kernel=poly; total time=   7.8s
# [CV] END ............C=10, degree=3, gamma=0.01, kernel=poly; total time=   7.7s
# [CV] END ............C=10, degree=3, gamma=0.01, kernel=poly; total time=   7.8s
# [CV] END ............C=10, degree=3, gamma=0.01, kernel=poly; total time=   7.7s
# [CV] END ...............C=10, degree=3, gamma=1, kernel=poly; total time=   7.7s
# [CV] END ...............C=10, degree=3, gamma=1, kernel=poly; total time=   7.7s
# [CV] END ...............C=10, degree=3, gamma=1, kernel=poly; total time=   7.6s
# [CV] END ...............C=10, degree=3, gamma=1, kernel=poly; total time=   7.7s
# [CV] END ...............C=10, degree=3, gamma=1, kernel=poly; total time=   7.6s
# {'C': 1, 'degree': 2, 'gamma': 0.001, 'kernel': 'poly'}
# [[234   0   0   0   0   0]
#  [  0  78   0   0   0   0]
#  [  0   0 189   0   0   0]
#  [  0   0   0 234   0   0]
#  [  0   0   0   0  45   0]
#  [  0   0   0   0   0 682]]
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00       234
#            2       1.00      1.00      1.00        78
#            3       1.00      1.00      1.00       189
#            4       1.00      1.00      1.00       234
#            5       1.00      1.00      1.00        45
#            6       1.00      1.00      1.00       682
#
#     accuracy                           1.00      1462
#    macro avg       1.00      1.00      1.00      1462
# weighted avg       1.00      1.00      1.00      1462

# %%
from sklearn.model_selection import GridSearchCV

'''
Sigmoid
'''
grid_predictions_s = { 'C': [0.11, 10, 100],'kernel': ['sigmoid']}
grid_s = GridSearchCV(SVC(),grid_predictions_s,refit=True,verbose=2)
grid_s.fit(train_features, y_train)
print(grid_s.best_params_)
grid_predictions_s = grid_s.predict(test_features)
print(confusion_matrix(y_test, grid_predictions_s))
print(classification_report(y_test,grid_predictions_s))
# Out:
# Fitting 5 folds for each of 3 candidates, totalling 15 fits
# [CV] END .............................C=0.11, kernel=sigmoid; total time=   8.8s
# [CV] END .............................C=0.11, kernel=sigmoid; total time=   9.2s
# [CV] END .............................C=0.11, kernel=sigmoid; total time=   9.3s
# [CV] END .............................C=0.11, kernel=sigmoid; total time=   9.0s
# [CV] END .............................C=0.11, kernel=sigmoid; total time=   9.2s
# [CV] END ...............................C=10, kernel=sigmoid; total time=   2.3s
# [CV] END ...............................C=10, kernel=sigmoid; total time=   2.4s
# [CV] END ...............................C=10, kernel=sigmoid; total time=   2.3s
# [CV] END ...............................C=10, kernel=sigmoid; total time=   2.7s
# [CV] END ...............................C=10, kernel=sigmoid; total time=   2.6s
# [CV] END ..............................C=100, kernel=sigmoid; total time=   1.7s
# [CV] END ..............................C=100, kernel=sigmoid; total time=   2.4s
# [CV] END ..............................C=100, kernel=sigmoid; total time=   2.1s
# [CV] END ..............................C=100, kernel=sigmoid; total time=   2.2s
# [CV] END ..............................C=100, kernel=sigmoid; total time=   2.5s
# {'C': 10, 'kernel': 'sigmoid'}
# [[212   0  12   3   0   7]
#  [  0  78   0   0   0   0]
#  [  4   0 171   6   0   8]
#  [ 16   0  25 137   0  56]
#  [  0   0   0   0  45   0]
#  [ 25   3  26  25   0 603]]
#               precision    recall  f1-score   support
#
#            1       0.82      0.91      0.86       234
#            2       0.96      1.00      0.98        78
#            3       0.73      0.90      0.81       189
#            4       0.80      0.59      0.68       234
#            5       1.00      1.00      1.00        45
#            6       0.89      0.88      0.89       682
#
#     accuracy                           0.85      1462
#    macro avg       0.87      0.88      0.87      1462
# weighted avg       0.85      0.85      0.85      1462

# %% [markdown]
# ## Training SVM model
# #### Hyperparameters are tuned based on the results from the grid searches

# %%
linear = svm.SVC(kernel='linear', C=100, gamma=0.12, decision_function_shape='ovo').fit(train_features, y_train)
rbf = svm.SVC(kernel='rbf', gamma=0.2, C=84, decision_function_shape='ovo').fit(train_features, y_train)
poly = svm.SVC(kernel='poly', degree=2, C=1, gamma=0.01, decision_function_shape='ovo').fit(train_features, y_train)
sig = svm.SVC(kernel='sigmoid', C=10, decision_function_shape='ovo').fit(train_features, y_train)

# %% [markdown]
# ## Predicting classes from the test set

# %%
linear_pred = linear.predict(test_features)
poly_pred = poly.predict(test_features)
rbf_pred = rbf.predict(test_features)
sig_pred = sig.predict(test_features)

# %% [markdown]
# ## Visualising and Evaluating Results

# %%
# retrieve the accuracy and print it for all 4 kernel functions
accuracy_lin = linear.score(test_features, y_test)
accuracy_poly = poly.score(test_features, y_test)
accuracy_rbf = rbf.score(test_features, y_test)
accuracy_sig = sig.score(test_features, y_test)

# %%
# creating a confusion matrix
fig, ax = plt.subplots(figsize=(8,8))         # Sample figsize in inches
print('Accuracy Linear Kernel:', accuracy_lin)
cm_lin = confusion_matrix(y_test, linear_pred)
ax = sns.heatmap(cm_lin, annot=True, cmap='Blues',annot_kws={"size": 14}, fmt='g',cbar=False)
print(classification_report(y_test, linear_pred))
# Out:
# Accuracy Linear Kernel: 1.0
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00       234
#            2       1.00      1.00      1.00        78
#            3       1.00      1.00      1.00       189
#            4       1.00      1.00      1.00       234
#            5       1.00      1.00      1.00        45
#            6       1.00      1.00      1.00       682
#
#     accuracy                           1.00      1462
#    macro avg       1.00      1.00      1.00      1462
# weighted avg       1.00      1.00      1.00      1462

# %%
print('Accuracy Polynomial Kernel:', accuracy_poly)
cm_poly = confusion_matrix(y_test, poly_pred)
fig, ax = plt.subplots(figsize=(8,8))         # Sample figsize in inches
ax = sns.heatmap(cm_poly, annot=True, cmap='Blues',annot_kws={"size": 14}, fmt='g',cbar=False)
print(classification_report(y_test, poly_pred))
# Out:
# Accuracy Polynomial Kernel: 1.0
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00       234
#            2       1.00      1.00      1.00        78
#            3       1.00      1.00      1.00       189
#            4       1.00      1.00      1.00       234
#            5       1.00      1.00      1.00        45
#            6       1.00      1.00      1.00       682
#
#     accuracy                           1.00      1462
#    macro avg       1.00      1.00      1.00      1462
# weighted avg       1.00      1.00      1.00      1462

# %%
print('Accuracy Radial Basis Kernel:', accuracy_rbf)
cm_rbf = confusion_matrix(y_test, rbf_pred)
ax = sns.heatmap(cm_rbf, annot=True, cmap='Blues',annot_kws={"size": 14}, fmt='g',cbar=False)
print(classification_report(y_test, rbf_pred))
# Out:
# Accuracy Radial Basis Kernel: 0.466484268125855
#               precision    recall  f1-score   support
#
#            1       0.00      0.00      0.00       234
#            2       0.00      0.00      0.00        78
#            3       0.00      0.00      0.00       189
#            4       0.00      0.00      0.00       234
#            5       0.00      0.00      0.00        45
#            6       0.47      1.00      0.64       682
#
#     accuracy                           0.47      1462
#    macro avg       0.08      0.17      0.11      1462
# weighted avg       0.22      0.47      0.30      1462
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
print('Accuracy Sigmoid Kernel:', accuracy_sig)
cm_sig = confusion_matrix(y_test, sig_pred)
ax = sns.heatmap(cm_sig, annot=True, cmap='Blues',annot_kws={"size": 14}, fmt='g',cbar=False)
print(classification_report(y_test, sig_pred))
# Out:
# Accuracy Sigmoid Kernel: 0.8522571819425444
#               precision    recall  f1-score   support
#
#            1       0.82      0.91      0.86       234
#            2       0.96      1.00      0.98        78
#            3       0.73      0.90      0.81       189
#            4       0.80      0.59      0.68       234
#            5       1.00      1.00      1.00        45
#            6       0.89      0.88      0.89       682
#
#     accuracy                           0.85      1462
#    macro avg       0.87      0.88      0.87      1462
# weighted avg       0.85      0.85      0.85      1462
